# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Steam Verileri

# %%
df = pd.read_csv("../dataset/games-features.csv")
df.head()
# Out:
#    QueryID  ResponseID                  QueryName               ResponseName  \
# 0       10          10             Counter-Strike             Counter-Strike
# 1       20          20      Team Fortress Classic      Team Fortress Classic
# 2       30          30              Day of Defeat              Day of Defeat
# 3       40          40         Deathmatch Classic         Deathmatch Classic
# 4       50          50  Half-Life: Opposing Force  Half-Life: Opposing Force
#
#   ReleaseDate  RequiredAge  DemoCount  DeveloperCount  DLCCount  Metacritic  \
# 0  Nov 1 2000            0          0               1         0          88
# 1  Apr 1 1999            0          0               1         0           0
# 2  May 1 2003            0          0               1         0          79
# 3  Jun 1 2001            0          0               1         0           0
# 4  Nov 1 1999            0          0               1         0           0
#
#    ...  LegalNotice  Reviews  \
# 0  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13357 entries, 0 to 13356
# Data columns (total 78 columns):
# QueryID                        13357 non-null int64
# ResponseID                     13357 non-null int64
# QueryName                      13356 non-null object
# ResponseName                   13357 non-null object
# ReleaseDate                    13357 non-null object
# RequiredAge                    13357 non-null int64
# DemoCount                      13357 non-null int64
# DeveloperCount                 13357 non-null int64
# DLCCount                       13357 non-null int64
# Metacritic                     13357 non-null int64
# MovieCount                     13357 non-null int64
# PackageCount                   13357 non-null int64
# RecommendationCount            13357 non-null int64
# PublisherCount                 13357 non-null int64
# ScreenshotCount                13357 non-null int64
# SteamSpyOwners                 13357 non-null int64
# ...

# %%
df.describe().T
# Out:
#                                count           mean           std   min  \
# QueryID                      13352.0  353707.457010  1.469342e+05  10.0
# ResponseID                   13352.0  353541.292690  1.470313e+05  10.0
# RequiredAge                  13352.0       0.838002  3.626344e+00   0.0
# DemoCount                    13352.0       0.089350  2.857835e-01   0.0
# DeveloperCount               13352.0       1.032430  4.371140e-01   0.0
# DLCCount                     13352.0       0.806246  1.003677e+01   0.0
# Metacritic                   13352.0      12.278910  2.750521e+01   0.0
# MovieCount                   13352.0       1.321150  1.178507e+00   0.0
# PackageCount                 13352.0       1.088451  8.553777e-01   0.0
# RecommendationCount          13352.0    1180.707310  1.517889e+04   0.0
# PublisherCount               13352.0       0.989664  3.370349e-01   0.0
# ScreenshotCount              13352.0       9.559916  6.440698e+00   0.0
# ...

# %% [markdown]
# ## Clear Data

# %%
df.isnull().values.any() #null deger control

# %%
df.dropna(inplace=True)#null degerler silindi
df.isnull().values.any()
# Out:
# False

# %%
df=df.drop(['QueryID',
         'DeveloperCount',
         'PackageCount','SteamSpyOwnersVariance','SteamSpyPlayersEstimate','SteamSpyPlayersVariance',
         'PublisherCount','AchievementHighlightedCount','PriceCurrency','Background',
         'DetailedDescrip','DRMNotice','ExtUserAcctNotice','HeaderImage','LegalNotice','Reviews'],axis=1)

# %%
df = df.drop("QueryName", axis=1)
df = df.rename(columns={"ResponseName": "AppName"})
df = df.drop("ResponseID", axis=1)
df = df.rename(columns={"ResponseID": "AppID"})
df = df.rename(columns={"MovieCount": "GameTrailerCount"})
df = df.rename(columns={"SteamSpyOwners": "UserCount"})
df['Email']=df.SupportEmail==" "
df = df.drop("SupportEmail", axis=1)
df['Websites']=df.Website==" "
df = df.drop("Website", axis=1)

# %%
df.head()
# Out:
#                      AppName ReleaseDate  RequiredAge  DemoCount  DLCCount  \
# 0             Counter-Strike  Nov 1 2000            0          0         0
# 1      Team Fortress Classic  Apr 1 1999            0          0         0
# 2              Day of Defeat  May 1 2003            0          0         0
# 3         Deathmatch Classic  Jun 1 2001            0          0         0
# 4  Half-Life: Opposing Force  Nov 1 1999            0          0         0
#
#    Metacritic  GameTrailerCount  RecommendationCount  ScreenshotCount  \
# 0          88                 0                68991               13
# 1           0                 0                 2439                5
# 2          79                 0                 2319                5
# 3           0                 0                  888                4
# 4           0                 0                 2934                5
#
#    UserCount  ...  ShortDescrip  \
# 0   13033334  ...
# 1    5399140  ...
# ...

# %% [markdown]
# ## Group By Data

# %%
df.RequiredAge.unique()
# Out:
# array([ 0, 17, 18, 16, 13, 15,  6, 12, 10, 14,  1,  7])

# %%
#yasa göre filtreleme
required_age = df.groupby('RequiredAge')['AppName'].nunique().to_frame()# yas sınırlarına göre oyun sayıları
required_age
# Out:
#              AppName
# RequiredAge
# 0              12549
# 1                  1
# 6                  2
# 7                  1
# 10                 9
# 12                10
# 13                82
# 14                 2
# 15                 9
# 16                37
# 17               414
# 18                79

# %%
#linux-windows-mac platforma göre sayılar
plt.clf()
df.groupby(['PlatformLinux','PlatformWindows','PlatformMac'])['AppName'].size().plot(kind='bar')
plt.show()

# %%
a = df.groupby(['CategorySinglePlayer','CategoryMultiplayer'])['AppName'].size()
a.plot(kind='bar')

# %%
#multi-single fitle
df_game = df.loc[df['GenreIsNonGame'] == False] #sadece oyunlar
df_game.groupby(['CategorySinglePlayer','CategoryMultiplayer'])['AppName'].size().plot(kind='bar')

# %%
df_price=df.groupby(['AppName','PriceFinal','UserCount'])['UserCount'].mean().sort_values(ascending=False).plot(kind='bar')
df_price.head()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(df.corr(), annot=True, linewidths=.5,fmt=".1f")#verileri correlation görsellestirme
df.boxplot()

# %%
total_hours = df['Hours'].groupby(df['Game']) 
fig, ax = plt.subplots(figsize=(15,7))
df['Hours'].groupby(df['Game']).count().plot(ax=ax)
